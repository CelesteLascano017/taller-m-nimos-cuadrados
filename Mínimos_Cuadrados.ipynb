# %% [markdown]
# # Taller 05 - Mínimos Cuadrados
#
# ### Celeste Lascano

# %% [markdown]
# 1\. Comprobar gráficamente y observar que la línea pase por esos puntos.

# %%
# Derivadas parciales para regresión lineal
# ####################################################################
def der_parcial_1(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 1 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """

    # coeficiente del término independiente
    c_ind = sum(ys)

    # coeficiente del parámetro 1
    c_1 = sum(xs)

    # coeficiente del parámetro 0
    c_0 = len(xs)

    return (c_1, c_0, c_ind)


def der_parcial_0(xs: list, ys: list) -> tuple[float, float, float]:
    """Retorna los coeficientes de la ecuación de la derivada parcial con respecto al parámetro 0 al reemplazar los valores ``xs`` y ``ys``. La ecuación es de la forma:
    c_1 * a_1 + c_0 * a_0 = c_ind


    ## Parameters

    ``xs``: lista de valores de x.

    ``ys``: lista de valores de y.

    ## Return

    ``c_1``: coeficiente del parámetro 1.

    ``c_0``: coeficiente del parámetro 0.

    ``c_ind``: coeficiente del término independiente.

    """
    c_1 = 0
    c_0 = 0
    c_ind = 0
    for xi, yi in zip(xs, ys):
        # coeficiente del término independiente
        c_ind += xi * yi

        # coeficiente del parámetro 1
        c_1 += xi * xi

        # coeficiente del parámetro 0
        c_0 += xi

    return (c_1, c_0, c_ind)

from src import ajustar_min_cuadrados

# UTILICE:
ajustar_min_cuadrados([5.4, 9.2, 12.3], [3.2, 0.7, -3.6], [der_parcial_1, der_parcial_0])
# Out:
# [12-15 17:48:52][INFO] Se ajustarán 2 parámetros.
# array([-0.97334636,  8.82767234])

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.array([5.4, 9.2, 12.3])
y = np.array([3.2, 0.7, -3.6])

n = len(x)


sum_x = np.sum(x)
sum_y = np.sum(y)
sum_x2 = np.sum(x**2)
sum_xy = np.sum(x * y)

m = (n * sum_xy - sum_x * sum_y) / (n * sum_x2 - sum_x**2)
b = (sum_y - m * sum_x) / n

print(f"m = {m}")
print(f"b = {b}")


x_line = np.linspace(min(x) - 1, max(x) + 1, 200)
y_line = m * x_line + b

plt.figure()
plt.scatter(x, y, color='black', label='Datos')
plt.plot(x_line, y_line, label='Recta')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Ajuste por mínimos cuadrados')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# m = -0.9733463578007232
# b = 8.827672341613152

# %%
from src import ajustar_min_cuadrados

# UTILICE:
ajustar_min_cuadrados([3.38,0.35,2.07,-0.45,-0.55,-1.06,-2.77,3.08,-3.98,-5, -3.18,-1.96,2.37,-1.66,4.09], [-0.04,1.28,0.65,2.18,1.70,1.96,3.36,0.18,3.35,4.16,2.95,2.34,0.38,1.75,-1.06], [der_parcial_1, der_parcial_0])
# Out:
# [12-15 17:48:59][INFO] Se ajustarán 2 parámetros.
# array([-0.50323259,  1.49919762])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos
xs = [3.38,0.35,2.07,-0.45,-0.55,-1.06,-2.77,3.08,-3.98,-5, -3.18,-1.96,2.37,-1.66,4.09]
ys = [-0.04,1.28,0.65,2.18,1.70,1.96,3.36,0.18,3.35,4.16,2.95,2.34,0.38,1.75,-1.06]

# Ajuste por mínimos cuadrados
a1, a0 = ajustar_min_cuadrados(xs, ys, [der_parcial_1, der_parcial_0])

# Recta ajustada
x_line = np.linspace(min(xs), max(xs), 100)
y_line = a1 * x_line + a0

# Gráfica
plt.figure()
plt.scatter(xs, ys)
plt.plot(x_line, y_line)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados")
plt.show()
# Out:
# [12-15 17:49:17][INFO] Se ajustarán 2 parámetros.

# %%
from src import ajustar_min_cuadrados

# UTILICE:
ajustar_min_cuadrados( [3.38, 0.35, 2.07, -0.45, -0.56, -1.06, -2.78, 3.08, -3.99, -5.00,
-3.18, -1.97, 2.37, -1.67, 4.09, -4.60, 2.68, 2.78, -3.79, -1.87], [15.65, -11.20, -4.00, 18.03, 7.94, 15.32, -4.40, 1.39, -11.92, -90.24,6.92, 28.35, -2.41, -5.47, 35.91, -55.53, 0.77, 4.79, -27.05, 2.85], [der_parcial_1, der_parcial_0])
# Out:
# [12-15 17:49:34][INFO] Se ajustarán 2 parámetros.
# array([ 5.68666556, -0.83754722])

# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos
xs = [3.38, 0.35, 2.07, -0.45, -0.56, -1.06, -2.78, 3.08, -3.99, -5.00,
-3.18, -1.97, 2.37, -1.67, 4.09, -4.60, 2.68, 2.78, -3.79, -1.87]
ys = [15.65, -11.20, -4.00, 18.03, 7.94, 15.32, -4.40, 1.39, -11.92, -90.24,6.92, 28.35, -2.41, -5.47, 35.91, -55.53, 0.77, 4.79, -27.05, 2.85]

# Ajuste por mínimos cuadrados
a1, a0 = ajustar_min_cuadrados(xs, ys, [der_parcial_1, der_parcial_0])

# Recta ajustada
x_line = np.linspace(min(xs), max(xs), 100)
y_line = a1 * x_line + a0

# Gráfica
plt.figure()
plt.scatter(xs, ys)
plt.plot(x_line, y_line)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados")
plt.show()
# Out:
# [12-15 17:49:53][INFO] Se ajustarán 2 parámetros.

# %%
import numpy as np
import matplotlib.pyplot as plt

xs = np.array([3.38, 0.35, 2.07, -0.45, -0.56, -1.06, -2.78, 3.08, -3.99, -5.00,
-3.18, -1.97, 2.37, -1.67, 4.09, -4.60, 2.68, 2.78, -3.79, -1.87
], dtype=float)

ys = np.array([
15.65, -11.20, -4.00, 18.03, 7.94, 15.32, -4.40, 1.39, -11.92, -90.24,6.92, 28.35, -2.41, -5.47, 35.91, -55.53, 0.77, 4.79, -27.05, 2.85
], dtype=float)

# %%
def ajustar_polinomio_min_cuadrados(xs, ys, grado):
    """
    Ajusta un polinomio de grado 'grado' por mínimos cuadrados
    a los datos (xs, ys).
    Devuelve los coeficientes [a0, a1, ..., a_grado].
    """
    # Matriz de diseño A: columnas [1, x, x^2, ..., x^grado]
    A = np.vander(xs, grado + 1, increasing=True)  # increasing=True => [x^0, x^1, ...]
    
    # Resolver mínimos cuadrados: A a ≈ y
    coefs, *_ = np.linalg.lstsq(A, ys, rcond=None)
    return coefs  # array de longitud grado+1

# %%
def evaluar_polinomio(coefs, x):
    """
    Evalúa el polinomio con coeficientes 'coefs'
    en los puntos x (escalar o array).
    coefs = [a0, a1, ..., an]
    """
    # coefs[0] + coefs[1] * x + coefs[2] * x**2 + ...
    # Usamos np.polyval pero ojo: espera coefs al revés.
    potencias = np.array([x**i for i in range(len(coefs))])
    return np.sum(coefs[:, np.newaxis] * potencias, axis=0)

# %%
grado = 3  # prueba con 2, luego con 3, 4, etc.

coefs = ajustar_polinomio_min_cuadrados(xs, ys, grado)
print("Coeficientes (a0, a1, ..., a_grado):")
print(coefs)
# Out:
# Coeficientes (a0, a1, ..., a_grado):
# [ 2.76228992 -8.88066397  0.03132741  1.04497792]

# %%
# Puntos para graficar la curva
x_plot = np.linspace(xs.min() - 0.1, xs.max() + 0.1, 400)
y_plot = evaluar_polinomio(coefs, x_plot)

plt.figure()
plt.scatter(xs, ys, label="Datos", s=30)
plt.plot(x_plot, y_plot, label=f"Polinomio grado {grado}")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Ajuste por mínimos cuadrados")
plt.legend()
plt.grid(True)
plt.show()
